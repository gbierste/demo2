# %%
import pandas as pd

# %%
df = pd.read_csv('movies_clean.csv', parse_dates=['release_date'])

# %%
credits = pd.read_csv('credits.csv')

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862
# ...                                                  ...     ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257
#
# [45476 rows x 3 columns]

# %%
#first drop duplicates in credit table
credits.drop_duplicates(subset = 'id', inplace = True)

# %%
#check duplicate remove
credits.id.value_counts()
# Out:
# 2047      1
# 8128      1
# 34170     1
# 38264     1
# 327029    1
#          ..
# 61999     1
# 33765     1
# 176867    1
# 376934    1
# 276895    1
# Name: id, Length: 45432, dtype: int64

# %%
df[~df.id.isin(credits.id)]
# Out:
#            id         title tagline release_date genres belongs_to_collection  \
# 42467  401840  School's out     NaN   2017-05-30    NaN                   NaN
#
#       original_language  budget_musd  revenue_musd production_companies  \
# 42467                es          NaN           NaN                  NaN
#
#       production_countries  vote_count  vote_average  popularity  runtime  \
# 42467                  NaN         0.0           NaN    0.207775      NaN
#
#                                                 overview spoken_languages  \
# 42467  Two high school kids mentored by a nightclub o...              NaN
#
#                             poster_path
# 42467  /4JI7Ica5I54xrU5T5htx9LwhHcV.jpg

# %%
df = df.merge(credits, how = 'left', left_on = 'id', right_on = 'id')

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44980  439050                       Subdue
# 44981  111109          Century of Birthing
# 44982   67758                     Betrayal
# 44983  227506             Satan Triumphant
# 44984  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44980         Rising and falling between a man and woman          NaT
# 44981                                                NaN   2011-11-17
# 44982                             A deadly game of wits.   2003-08-01
# 44983                                                NaN   1917-10-21
# 44984                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 44980              Drama|Family                             NaN
# 44981                     Drama                             NaN
# 44982     Action|Drama|Thriller                             NaN
# 44983                       NaN                             NaN
# 44984                       NaN                             NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en         30.0    373.554033
# 1                    en         65.0    262.797249
# 2                    en          NaN           NaN
# 3                    en         16.0     81.452156
# 4                    en          NaN     76.578911
# ...                 ...          ...           ...
# 44980                fa          NaN           NaN
# 44981                tl          NaN           NaN
# 44982                en          NaN           NaN
# 44983                en          NaN           NaN
# 44984                en          NaN           NaN
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 44980                                                NaN
# 44981                                        Sine Olivia
# 44982                            American World Pictures
# 44983                                          Yermoliev
# 44984                                                NaN
#
#            production_countries  vote_count  vote_average  popularity  \
# 0      United States of America      5415.0           7.7   21.946943
# 1      United States of America      2413.0           6.9   17.015539
# 2      United States of America        92.0           6.5   11.712900
# 3      United States of America        34.0           6.1    3.859495
# 4      United States of America       173.0           5.7    8.387519
# ...                         ...         ...           ...         ...
# 44980                      Iran         1.0           4.0    0.072051
# 44981               Philippines         3.0           9.0    0.178241
# 44982  United States of America         6.0           3.8    0.903007
# 44983                    Russia         0.0           NaN    0.003503
# 44984            United Kingdom         0.0           NaN    0.163015
#
#        runtime                                           overview  \
# 0         81.0  Led by Woody, Andy's toys live happily in his ...
# 1        104.0  When siblings Judy and Peter discover an encha...
# 2        101.0  A family wedding reignites the ancient feud be...
# 3        127.0  Cheated on, mistreated and stepped on, the wom...
# 4        106.0  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 44980     90.0        Rising and falling between a man and woman.
# 44981    360.0  An artist struggles to finish his work while a...
# 44982     90.0  When one of her hits goes wrong, a professiona...
# 44983     87.0  In a small town live two brothers, one a minis...
# 44984     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                       poster_path  \
# 0               English  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      English|Français  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2               English  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3               English  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4               English  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                 ...                               ...
# 44980             فارسی  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 44981               NaN  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 44982           English  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 44983               NaN  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 44984           English  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 44980  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 44981  [{'cast_id': 1002, 'character': 'Sister Angela...
# 44982  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 44983  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44984                                                 []
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 44980  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44981  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44982  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44983  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44984  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [44985 rows x 20 columns]

# %%
#clean cast column
import ast
import numpy as np

# %%
df.cast = df.cast.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\gbier\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-21-4a982ca2d942>", line 1, in <module>
#     df.cast = df.cast.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)
#
#   File "C:\Users\gbier\anaconda3\lib\site-packages\pandas\core\series.py", line 3848, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
#
#   File "pandas\_libs\lib.pyx", line 2329, in pandas._libs.lib.map_infer
#
#   File "<ipython-input-21-4a982ca2d942>", line 1, in <lambda>
#     df.cast = df.cast.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)
#
#   File "C:\Users\gbier\anaconda3\lib\ast.py", line 59, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File "C:\Users\gbier\anaconda3\lib\ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
#         ^
# SyntaxError: invalid syntax

# %%
df.cast
# Out:
# 0        [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1        [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2        [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3        [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4        [{'cast_id': 1, 'character': 'George Banks', '...
#                                ...
# 44980    [{'cast_id': 0, 'character': '', 'credit_id': ...
# 44981    [{'cast_id': 1002, 'character': 'Sister Angela...
# 44982    [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 44983    [{'cast_id': 2, 'character': '', 'credit_id': ...
# 44984                                                   []
# Name: cast, Length: 44985, dtype: object

# %%
#can put to dataframe
pd.DataFrame(df.cast[0])
# Out:
#     cast_id                character                 credit_id  gender  \
# 0        14            Woody (voice)  52fe4284c3a36847f8024f95       2
# 1        15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2
# 2        16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2
# 3        17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2
# 4        18              Rex (voice)  52fe4284c3a36847f8024fa5       2
# 5        19             Hamm (voice)  52fe4284c3a36847f8024fa9       2
# 6        20          Bo Peep (voice)  52fe4284c3a36847f8024fad       1
# 7        26             Andy (voice)  52fe4284c3a36847f8024fc1       0
# 8        22              Sid (voice)  52fe4284c3a36847f8024fb1       2
# 9        23       Mrs. Davis (voice)  52fe4284c3a36847f8024fb5       1
# 10       24         Sergeant (voice)  52fe4284c3a36847f8024fb9       2
# 11       25           Hannah (voice)  52fe4284c3a36847f8024fbd       1
# 12       27     TV Announcer (voice)  52fe4284c3a36847f8024fc5       2
#
#          id               name  order                      profile_path
# 0        31          Tom Hanks      0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 1     12898          Tim Allen      1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 2      7167        Don Rickles      2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 3     12899         Jim Varney      3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 4     12900      Wallace Shawn      4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg
# 5      7907  John Ratzenberger      5  /yGechiKWL6TJDfVE2KPSJYqdMsY.jpg
# 6      8873        Annie Potts      6  /eryXT84RL41jHSJcMy4kS3u9y6w.jpg
# 7   1116442        John Morris      7  /vYGyvK4LzeaUCoNSHtsuqJUY15M.jpg
# 8     12901    Erik von Detten      8  /twnF1ZaJ1FUNUuo6xLXwcxjayBE.jpg
# 9     12133     Laurie Metcalf      9  /unMMIT60eoBM2sN2nyR7EZ2BvvD.jpg
# 10     8655       R. Lee Ermey     10  /r8GBqFBjypLUP9VVqDqfZ7wYbSs.jpg
# 11    12903      Sarah Freeman     11                              None
# 12    37221      Penn Jillette     12  /zmAaXUdx12NRsssgHbk1T31j2x9.jpg

# %%
df["cast_size"] = df.cast.apply(lambda x: len(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-3b3b9bd27b49> in <module>
# ----> 1 df["cast_size"] = df.cast.apply(lambda x: len(x))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-20-3b3b9bd27b49> in <lambda>(x)
# ----> 1 df["cast_size"] = df.cast.apply(lambda x: len(x))
#
# TypeError: object of type 'float' has no len()

# %%
df.cast = df.cast.apply(lambda x: "|".join(i['name'] for i in x) if isinstance(x, list) else np.nan)

# %%
df.cast.value_counts().head(50)
# Out:
#                                           2359
# Georges Méliès                              24
# Louis Theroux                               15
# Mel Blanc                                   12
# Jimmy Carr                                   9
# David Attenborough                           8
# George Carlin                                8
# Werner Herzog                                8
# Louis C.K.                                   8
# Patton Oswalt                                6
# Jim Jefferies                                6
# Doug Stanhope                                6
# Trevor Noah                                  6
# Ricky Gervais                                6
# Kenneth Branagh                              5
# Eddie Izzard                                 5
# Dylan Moran                                  5
# Jim Gaffigan                                 5
# Lewis Black                                  5
# Bill Burr                                    5
# Bill Maher                                   5
# Robin Williams                               4
# Craig Ferguson                               4
# Walt Disney                                  4
# Jeff Dunham                                  4
# Bill Hicks                                   4
# Lisa Lampanelli                              4
# Russell Brand                                4
# Slavoj Žižek                                 4
# Margaret Cho                                 4
# John Pilger                                  4
# Katt Williams                                4
# Dave Attell                                  4
# Hannibal Buress                              4
# Don Hertzfeldt                               4
# Spalding Gray                                3
# David Lynch                                  3
# Peter Sallis                                 3
# Gabriel Iglesias                             3
# Wanda Sykes                                  3
# Noam Chomsky                                 3
# Sebastian Maniscalco                         3
# Chris Rock                                   3
# Iliza Shlesinger                             3
# Tilda Swinton                                3
# Amy Schumer                                  3
# Mel Blanc|Arthur Q. Bryan                    3
# Jimi Hendrix|Billy Cox|Mitch Mitchell        3
# Buster Keaton|Virginia Fox|Joe Roberts       3
# Russell Howard                               3
# Name: cast, dtype: int64

# %%
df.cast.replace("", np.nan, inplace = True)

# %%
df.crew = df.crew.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.crew
# Out:
# 0        [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1        [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2        [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3        [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4        [{'credit_id': '52fe44959251416c75039ed7', 'de...
#                                ...
# 44980    [{'credit_id': '5894a97d925141426c00818c', 'de...
# 44981    [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 44982    [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 44983    [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 44984    [{'credit_id': '593e676c92514105b702e68e', 'de...
# Name: crew, Length: 44985, dtype: object

# %%
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i ['name']
    return np.nan
